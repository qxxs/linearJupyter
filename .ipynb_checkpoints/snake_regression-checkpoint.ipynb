# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score, mean_squared_error

# %%
df = pd.read_csv('snakes_count_100.csv')
df.head()
# Out:
#    Game Number   "Game Length"
# 0            1              13
# 1            2              15
# 2            3              18
# 3            4              19
# 4            5              22

# %%
X = df['Game Number'].values.reshape(-1, 1) 
y = df[' "Game Length"'].values

# %%
model = LinearRegression()
model.fit(X, y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)

# %%
r2 = r2_score(y, y_pred)
mse = mean_squared_error(y, y_pred)

# %%
print(f'R-squared score: {r2:.4f}')
print(f'Mean Squared Error: {mse:.4f}')
print(f'Slope: {model.coef_[0]:.4f}')
print(f'Intercept: {model.intercept_:.4f}')
# Out:
# R-squared score: 0.9997
# Mean Squared Error: 0.8171
# Slope: 1.9759
# Intercept: 10.2158

# %%
plt.figure(figsize=(10, 6))
plt.scatter(X, y, color='blue', label='Actual Data')
plt.plot(X, y_pred, color='red', label='Regression Line')
plt.xlabel('Game Number')
plt.ylabel('Game Length')
plt.title('Linear Regression: Game Length vs Game Number')
plt.legend()
plt.grid(True)
plt.show()

# %%
  new_games = np.array([101, 102, 103]).reshape(-1, 1)
  predictions = model.predict(new_games)
  print(predictions)
# Out:
# [209.78424242 211.76016802 213.73609361]
